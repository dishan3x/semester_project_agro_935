# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as  np

# %%
df = pd.read_csv('dataSets/mauna_loa_co2.csv')
df.head()
# Out:
#    year  month  co2_ppm
# 0  1958      3   315.71
# 1  1958      4   317.45
# 2  1958      5   317.50
# 3  1958      6   317.10
# 4  1958      7   315.86

# %%
df.tail()
# Out:
#      year  month  co2_ppm
# 724  2018      7   408.71
# 725  2018      8   406.99
# 726  2018      9   405.51
# 727  2018     10   406.00
# 728  2018     11   408.02

# %%
df['month']
# Out:
# 0       3
# 1       4
# 2       5
# 3       6
# 4       7
#        ..
# 724     7
# 725     8
# 726     9
# 727    10
# 728    11
# Name: month, Length: 729, dtype: int64

# %%
df['decimal_date'] = df['year'] + df['month']/12
df
# Out:
#      year  month  co2_ppm  decimal_date
# 0    1958      3   315.71   1958.250000
# 1    1958      4   317.45   1958.333333
# 2    1958      5   317.50   1958.416667
# 3    1958      6   317.10   1958.500000
# 4    1958      7   315.86   1958.583333
# ..    ...    ...      ...           ...
# 724  2018      7   408.71   2018.583333
# 725  2018      8   406.99   2018.666667
# 726  2018      9   405.51   2018.750000
# 727  2018     10   406.00   2018.833333
# 728  2018     11   408.02   2018.916667
#
# [729 rows x 4 columns]

# %%
plt.figure(figsize=(6,4),dpi=300)
plt.plot(df["decimal_date"],df["co2_ppm"])
plt.show()

# %%
#print(plt.rcParams.items)
idx_2010s = df["year"] >= 2010
df_2010s = df[idx_2010s]
df_2010s.head()
# Out:
#      year  month  co2_ppm  decimal_date
# 622  2010      1   388.71   2010.083333
# 623  2010      2   390.20   2010.166667
# 624  2010      3   391.17   2010.250000
# 625  2010      4   392.46   2010.333333
# 626  2010      5   393.00   2010.416667

# %%
plt.figure()
plt.plot(df_2010s['decimal_date'],df_2010s['co2_ppm'])
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)

plt.tight_layout(); #remove overlapping and tighten it for a subpot
